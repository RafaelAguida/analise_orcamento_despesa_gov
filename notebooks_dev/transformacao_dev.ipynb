# %%
import os
import shutil
import pandas as pd
pd.set_option('display.max_columns', None)

# Fonte dos dados - https://portaldatransparencia.gov.br/download-de-dados/orcamento-despesa
# Dicionário de dados arquivos brutos - https://portaldatransparencia.gov.br/pagina-interna/603417-dicionario-de-dados-orcamento-da-despesa

# %%
# Lê o arquivo csv da pasta 'arquivos_silver/entrada', move para 'arquivos_silver/lidos' e faz algumas transformações. No final armazena em camada gold para ser carregado

# Diretórios
silver_entrada = "../arquivos_silver/entrada"
silver_lidos = "../arquivos_silver/lidos"
gold_entrada = "../arquivos_gold/entrada"

# Lê o csv
fatoOrcamentoDespesa = pd.read_csv(
    silver_entrada + '/fatoOrcamentoDespesa.csv',
    sep=";", 
    encoding="ISO-8859-1", 
    low_memory=False
)

# Mover o arquivo csv para a pasta 'arquivos_silver/lidos'
path_silver_lidos = os.path.join(silver_entrada, 'fatoOrcamentoDespesa.csv')
shutil.move(path_silver_lidos, os.path.join(silver_lidos, 'fatoOrcamentoDespesa.csv'))
print(f"Movido para {silver_lidos}: fatoOrcamentoDespesa.csv")
# Out:
# Movido para ../arquivos_silver/lidos: fatoOrcamentoDespesa.csv

# %%
fatoOrcamentoDespesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301903 entries, 0 to 301902
# Data columns (total 27 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   EXERCÍCIO                                                       301903 non-null  int64
#  1   CÓDIGO ÓRGÃO SUPERIOR                                           301903 non-null  int64
#  2   NOME ÓRGÃO SUPERIOR                                             301903 non-null  object
#  3   CÓDIGO ÓRGÃO SUBORDINADO                                        301903 non-null  int64
#  4   NOME ÓRGÃO SUBORDINADO                                          301903 non-null  object
#  5   CÓDIGO UNIDADE ORÇAMENTÁRIA                                     301903 non-null  int64
#  6   NOME UNIDADE ORÇAMENTÁRIA                                       301903 non-null  object
#  7   CÓDIGO FUNÇÃO                                                   301903 non-null  int64
#  8   NOME FUNÇÃO                                                     301903 non-null  object
#  9   CÓDIGO SUBFUNÇÃO                                                301903 non-null  int64
#  10  NOME SUBFUNÇÃO                                                  301903 non-null  object
#  11  CÓDIGO PROGRAMA ORÇAMENTÁRIO                                    301903 non-null  int64
#  12  NOME PROGRAMA ORÇAMENTÁRIO                                      301903 non-null  object
#  13  CÓDIGO AÇÃO                                                     301903 non-null  object
#  14  NOME AÇÃO                                                       301903 non-null  object
#  15  CÓDIGO CATEGORIA ECONÔMICA                                      301903 non-null  object
#  16  NOME CATEGORIA ECONÔMICA                                        301903 non-null  object
#  17  CÓDIGO GRUPO DE DESPESA                                         301903 non-null  object
#  18  NOME GRUPO DE DESPESA                                           301903 non-null  object
#  19  CÓDIGO ELEMENTO DE DESPESA                                      301903 non-null  int64
#  20  NOME ELEMENTO DE DESPESA                                        301903 non-null  object
#  21  ORÇAMENTO INICIAL (R$)                                          301903 non-null  object
#  22  ORÇAMENTO ATUALIZADO (R$)                                       301903 non-null  object
#  23  ORÇAMENTO EMPENHADO (R$)                                        301903 non-null  object
#  24  ORÇAMENTO REALIZADO (R$)                                        301903 non-null  object
#  25  % REALIZADO DO ORÇAMENTO (COM RELAÇÃO AO ORÇAMENTO ATUALIZADO)  301903 non-null  object
#  26  origem                                                          301903 non-null  object
# dtypes: int64(8), object(19)
# memory usage: 62.2+ MB

# %%
fatoOrcamentoDespesa.head(2)
# Out:
#    EXERCÍCIO  CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  \
# 0       2014                  20000  Presidência da República
# 1       2014                  20000  Presidência da República
#
#    CÓDIGO ÓRGÃO SUBORDINADO         NOME ÓRGÃO SUBORDINADO  \
# 0                     20415  Empresa Brasil de Comunicação
# 1                     20415  Empresa Brasil de Comunicação
#
#    CÓDIGO UNIDADE ORÇAMENTÁRIA      NOME UNIDADE ORÇAMENTÁRIA  CÓDIGO FUNÇÃO  \
# 0                        20415  EMPRESA BRASIL DE COMUNICACAO             24
# 1                        20415  EMPRESA BRASIL DE COMUNICACAO             24
#
#     NOME FUNÇÃO  CÓDIGO SUBFUNÇÃO       NOME SUBFUNÇÃO  \
# 0  Comunicações               122  Administração geral
# 1  Comunicações               122  Administração geral
#
#    CÓDIGO PROGRAMA ORÇAMENTÁRIO  \
# 0                          2101
# 1                          2101
#
#                           NOME PROGRAMA ORÇAMENTÁRIO CÓDIGO AÇÃO  \
# 0  PROGRAMA DE GESTAO E MANUTENCAO DA PRESIDENCIA...        2000
# 1  PROGRAMA DE GESTAO E MANUTENCAO DA PRESIDENCIA...        20TP
#
#                              NOME AÇÃO CÓDIGO CATEGORIA ECONÔMICA  \
# 0             ADMINISTRACAO DA UNIDADE                          3
# 1  PAGAMENTO DE PESSOAL ATIVO DA UNIAO                          3
#
#   NOME CATEGORIA ECONÔMICA CÓDIGO GRUPO DE DESPESA  \
# 0         DESPESA CORRENTE                       3
# 1         DESPESA CORRENTE                       1
#
#         NOME GRUPO DE DESPESA  CÓDIGO ELEMENTO DE DESPESA  \
# 0   Outras Despesas Correntes                          32
# 1  Pessoal e Encargos Sociais                          92
#
#                             NOME ELEMENTO DE DESPESA ORÇAMENTO INICIAL (R$)  \
# 0  Material, Bem ou Serviço para Distribuição Gra...               11006,00
# 1                  Despesas de Exercícios Anteriores              903193,21
#
#   ORÇAMENTO ATUALIZADO (R$) ORÇAMENTO EMPENHADO (R$) ORÇAMENTO REALIZADO (R$)  \
# 0                  11006,00                 11006,00                 11006,00
# 1                 903193,21                900065,21                900065,21
#
#   % REALIZADO DO ORÇAMENTO (COM RELAÇÃO AO ORÇAMENTO ATUALIZADO)  \
# 0                                            100,00%
# 1                                             99,65%
#
#                       origem
# 0  2014_OrcamentoDespesa.zip
# 1  2014_OrcamentoDespesa.zip

# %%
# Percorre as colunas da lista, para substituir "%" por nada, "," por "." e '.zip' por nada. Depois converte para float
columns_to_float = [
    'ORÇAMENTO INICIAL (R$)', 
    'ORÇAMENTO ATUALIZADO (R$)', 
    'ORÇAMENTO EMPENHADO (R$)', 
    'ORÇAMENTO REALIZADO (R$)', 
    '% REALIZADO DO ORÇAMENTO (COM RELAÇÃO AO ORÇAMENTO ATUALIZADO)',
    'origem'
]

for col in columns_to_float:
    if col == '% REALIZADO DO ORÇAMENTO (COM RELAÇÃO AO ORÇAMENTO ATUALIZADO)':
        fatoOrcamentoDespesa[col] = fatoOrcamentoDespesa[col].str.replace('%', '').str.replace(',', '.')
    elif col == 'origem':
        fatoOrcamentoDespesa[col] = fatoOrcamentoDespesa[col].str.replace('.zip', '')
    else:
        fatoOrcamentoDespesa[col] = fatoOrcamentoDespesa[col].str.replace(',', '.')

    if col != 'origem':
        fatoOrcamentoDespesa[col] = fatoOrcamentoDespesa[col].astype(float) # Converte para float depois das substituições
    else:
        pass

# %%
fatoOrcamentoDespesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301903 entries, 0 to 301902
# Data columns (total 27 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   EXERCÍCIO                                                       301903 non-null  int64
#  1   CÓDIGO ÓRGÃO SUPERIOR                                           301903 non-null  int64
#  2   NOME ÓRGÃO SUPERIOR                                             301903 non-null  object
#  3   CÓDIGO ÓRGÃO SUBORDINADO                                        301903 non-null  int64
#  4   NOME ÓRGÃO SUBORDINADO                                          301903 non-null  object
#  5   CÓDIGO UNIDADE ORÇAMENTÁRIA                                     301903 non-null  int64
#  6   NOME UNIDADE ORÇAMENTÁRIA                                       301903 non-null  object
#  7   CÓDIGO FUNÇÃO                                                   301903 non-null  int64
#  8   NOME FUNÇÃO                                                     301903 non-null  object
#  9   CÓDIGO SUBFUNÇÃO                                                301903 non-null  int64
#  10  NOME SUBFUNÇÃO                                                  301903 non-null  object
#  11  CÓDIGO PROGRAMA ORÇAMENTÁRIO                                    301903 non-null  int64
#  12  NOME PROGRAMA ORÇAMENTÁRIO                                      301903 non-null  object
#  13  CÓDIGO AÇÃO                                                     301903 non-null  object
#  14  NOME AÇÃO                                                       301903 non-null  object
#  15  CÓDIGO CATEGORIA ECONÔMICA                                      301903 non-null  object
#  16  NOME CATEGORIA ECONÔMICA                                        301903 non-null  object
#  17  CÓDIGO GRUPO DE DESPESA                                         301903 non-null  object
#  18  NOME GRUPO DE DESPESA                                           301903 non-null  object
#  19  CÓDIGO ELEMENTO DE DESPESA                                      301903 non-null  int64
#  20  NOME ELEMENTO DE DESPESA                                        301903 non-null  object
#  21  ORÇAMENTO INICIAL (R$)                                          301903 non-null  float64
#  22  ORÇAMENTO ATUALIZADO (R$)                                       301903 non-null  float64
#  23  ORÇAMENTO EMPENHADO (R$)                                        301903 non-null  float64
#  24  ORÇAMENTO REALIZADO (R$)                                        301903 non-null  float64
#  25  % REALIZADO DO ORÇAMENTO (COM RELAÇÃO AO ORÇAMENTO ATUALIZADO)  301903 non-null  float64
#  26  origem                                                          301903 non-null  object
# dtypes: float64(5), int64(8), object(14)
# memory usage: 62.2+ MB

# %%
fatoOrcamentoDespesa.head(2)
# Out:
#    EXERCÍCIO  CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  \
# 0       2014                  20000  Presidência da República
# 1       2014                  20000  Presidência da República
#
#    CÓDIGO ÓRGÃO SUBORDINADO         NOME ÓRGÃO SUBORDINADO  \
# 0                     20415  Empresa Brasil de Comunicação
# 1                     20415  Empresa Brasil de Comunicação
#
#    CÓDIGO UNIDADE ORÇAMENTÁRIA      NOME UNIDADE ORÇAMENTÁRIA  CÓDIGO FUNÇÃO  \
# 0                        20415  EMPRESA BRASIL DE COMUNICACAO             24
# 1                        20415  EMPRESA BRASIL DE COMUNICACAO             24
#
#     NOME FUNÇÃO  CÓDIGO SUBFUNÇÃO       NOME SUBFUNÇÃO  \
# 0  Comunicações               122  Administração geral
# 1  Comunicações               122  Administração geral
#
#    CÓDIGO PROGRAMA ORÇAMENTÁRIO  \
# 0                          2101
# 1                          2101
#
#                           NOME PROGRAMA ORÇAMENTÁRIO CÓDIGO AÇÃO  \
# 0  PROGRAMA DE GESTAO E MANUTENCAO DA PRESIDENCIA...        2000
# 1  PROGRAMA DE GESTAO E MANUTENCAO DA PRESIDENCIA...        20TP
#
#                              NOME AÇÃO CÓDIGO CATEGORIA ECONÔMICA  \
# 0             ADMINISTRACAO DA UNIDADE                          3
# 1  PAGAMENTO DE PESSOAL ATIVO DA UNIAO                          3
#
#   NOME CATEGORIA ECONÔMICA CÓDIGO GRUPO DE DESPESA  \
# 0         DESPESA CORRENTE                       3
# 1         DESPESA CORRENTE                       1
#
#         NOME GRUPO DE DESPESA  CÓDIGO ELEMENTO DE DESPESA  \
# 0   Outras Despesas Correntes                          32
# 1  Pessoal e Encargos Sociais                          92
#
#                             NOME ELEMENTO DE DESPESA  ORÇAMENTO INICIAL (R$)  \
# 0  Material, Bem ou Serviço para Distribuição Gra...                11006.00
# 1                  Despesas de Exercícios Anteriores               903193.21
#
#    ORÇAMENTO ATUALIZADO (R$)  ORÇAMENTO EMPENHADO (R$)  \
# 0                   11006.00                  11006.00
# 1                  903193.21                 900065.21
#
#    ORÇAMENTO REALIZADO (R$)  \
# 0                  11006.00
# 1                 900065.21
#
#    % REALIZADO DO ORÇAMENTO (COM RELAÇÃO AO ORÇAMENTO ATUALIZADO)  \
# 0                                             100.00
# 1                                              99.65
#
#                   origem
# 0  2014_OrcamentoDespesa
# 1  2014_OrcamentoDespesa

# %%
# Renomeando as colunas para alinhar com a regra do banco de dados da organizacao
fatoOrcamentoDespesa = fatoOrcamentoDespesa.rename(columns={
    'EXERCÍCIO': 'ano_exercicio',
    'CÓDIGO ÓRGÃO SUPERIOR': 'cod_orgao_superior',
    'NOME ÓRGÃO SUPERIOR': 'nome_orgao_superior',
    'CÓDIGO ÓRGÃO SUBORDINADO': 'cod_orgao_subordinado',
    'NOME ÓRGÃO SUBORDINADO': 'nome_orgao_subordinado',
    'CÓDIGO UNIDADE ORÇAMENTÁRIA': 'cod_unidade_orcamentaria',
    'NOME UNIDADE ORÇAMENTÁRIA': 'nome_unidade_orcamentaria',
    'CÓDIGO FUNÇÃO': 'cod_funcao',
    'NOME FUNÇÃO': 'nome_funcao',
    'CÓDIGO SUBFUNÇÃO': 'cod_subfuncao',
    'NOME SUBFUNÇÃO': 'nome_subfuncao',
    'CÓDIGO PROGRAMA ORÇAMENTÁRIO': 'cod_programa_orcamentario',
    'NOME PROGRAMA ORÇAMENTÁRIO': 'nome_programa_orcamentario',
    'CÓDIGO AÇÃO': 'cod_acao',
    'NOME AÇÃO': 'nome_acao',
    'CÓDIGO CATEGORIA ECONÔMICA': 'cod_categoria_economica',
    'NOME CATEGORIA ECONÔMICA': 'nome_categoria_economica',
    'CÓDIGO GRUPO DE DESPESA': 'cod_grupo_despesa',
    'NOME GRUPO DE DESPESA': 'nome_grupo_despesa',
    'CÓDIGO ELEMENTO DE DESPESA': 'cod_elemento_despesa',
    'NOME ELEMENTO DE DESPESA': 'nome_elemento_despesa',
    'ORÇAMENTO INICIAL (R$)': 'orcamento_inicial',
    'ORÇAMENTO ATUALIZADO (R$)': 'orcamento_atualizado',
    'ORÇAMENTO EMPENHADO (R$)': 'orcamento_empenhado',
    'ORÇAMENTO REALIZADO (R$)': 'orcamento_realizado',
    '% REALIZADO DO ORÇAMENTO (COM RELAÇÃO AO ORÇAMENTO ATUALIZADO)': 'percentual_realizado_orcamento_atualizado'
})

# %%
fatoOrcamentoDespesa.head(2)
# Out:
#    ano_exercicio  cod_orgao_superior       nome_orgao_superior  \
# 0           2014               20000  Presidência da República
# 1           2014               20000  Presidência da República
#
#    cod_orgao_subordinado         nome_orgao_subordinado  \
# 0                  20415  Empresa Brasil de Comunicação
# 1                  20415  Empresa Brasil de Comunicação
#
#    cod_unidade_orcamentaria      nome_unidade_orcamentaria  cod_funcao  \
# 0                     20415  EMPRESA BRASIL DE COMUNICACAO          24
# 1                     20415  EMPRESA BRASIL DE COMUNICACAO          24
#
#     nome_funcao  cod_subfuncao       nome_subfuncao  \
# 0  Comunicações            122  Administração geral
# 1  Comunicações            122  Administração geral
#
#    cod_programa_orcamentario  \
# 0                       2101
# 1                       2101
#
#                           nome_programa_orcamentario cod_acao  \
# 0  PROGRAMA DE GESTAO E MANUTENCAO DA PRESIDENCIA...     2000
# 1  PROGRAMA DE GESTAO E MANUTENCAO DA PRESIDENCIA...     20TP
#
#                              nome_acao cod_categoria_economica  \
# 0             ADMINISTRACAO DA UNIDADE                       3
# 1  PAGAMENTO DE PESSOAL ATIVO DA UNIAO                       3
#
#   nome_categoria_economica cod_grupo_despesa          nome_grupo_despesa  \
# 0         DESPESA CORRENTE                 3   Outras Despesas Correntes
# 1         DESPESA CORRENTE                 1  Pessoal e Encargos Sociais
#
#    cod_elemento_despesa                              nome_elemento_despesa  \
# 0                    32  Material, Bem ou Serviço para Distribuição Gra...
# 1                    92                  Despesas de Exercícios Anteriores
#
#    orcamento_inicial  orcamento_atualizado  orcamento_empenhado  \
# 0           11006.00              11006.00             11006.00
# 1          903193.21             903193.21            900065.21
#
#    orcamento_realizado  percentual_realizado_orcamento_atualizado  \
# 0             11006.00                                     100.00
# 1            900065.21                                      99.65
#
#                   origem
# 0  2014_OrcamentoDespesa
# 1  2014_OrcamentoDespesa

# %%
# Armazena o df transformado na pasta 'arquivos_gold/entrada'
output_path = os.path.join(gold_entrada, "fatoOrcamentoDespesa.csv")
fatoOrcamentoDespesa.to_csv(output_path, index=False, sep=";", encoding="ISO-8859-1")

print('Transformação concluida com sucesso!')
# Out:
# Transformação concluida com sucesso!
